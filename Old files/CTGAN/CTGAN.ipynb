# %%
# %pip install ctgan

# %%
import ctgan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

data = pd.read_csv("./gene_expression_39_40_50.csv")
classes = pd.read_csv("./meta_50_three_class(1).csv")

# %% [markdown]
# # Helper Functions

# %%
def plot_tsne(gendata, actual_path, name, epoch = None):
    n_patients, n_genes = gendata.shape
    print(gendata.shape)
    df = pd.read_csv(actual_path)
    df.reset_index(drop=True, inplace=True)
    df = df.values
    df = df[:, 1:]
    print(df.shape)
    # df = df[:n_patients, :n_genes]
    df = df.astype(np.float64)
    labels_train = (np.ones((df.shape[0], 1))).astype(np.float64)
    labels_train = pd.DataFrame(labels_train, columns = ['label'])
    train_map = {1:"Train_Data"}
    df = pd.concat([pd.DataFrame(df), labels_train], axis = 1)
    df['label'] = df['label'].map(train_map)

    labels_test = (np.zeros((gendata.shape[0], 1))).astype(np.float64)
    labels_test = pd.DataFrame(labels_test, columns = ['label'])
    gen_map = {0: "Gen_Data"}
    gendata = pd.concat([gendata, labels_test], axis=1)
    gendata.to_csv("./gendata.csv")
    gendata['label'] = gendata['label'].map(gen_map)

    df.reset_index(drop=True, inplace=True)
    # df = df.iloc[]
    dfeatures = pd.concat([df, gendata], ignore_index=True,axis=0)
    print(dfeatures)
    labels = dfeatures[['label']]
    dfeatures.drop(['label'], axis=1, inplace=True)
    df.drop(['label'], axis=1, inplace=True)
    gendata.drop(['label'], axis=1, inplace=True)
    
    X_embedded = TSNE(n_components=2, random_state=0, perplexity=100).fit_transform(dfeatures)
    X_embedded = pd.DataFrame(X_embedded, columns = ['dim1', 'dim2'])
    X_embedded = pd.DataFrame(np.hstack([np.array(X_embedded), np.array(labels)]))
    X_embedded.columns = ['dim1','dim2','label']

    sns_fig = sns.lmplot(x='dim1', y='dim2', data=X_embedded,fit_reg=False, hue='label'
                    , markers=["x","o"],
                    palette = dict(Gen_Data= (0.568, 0.508, 0.084) ,Train_Data= (0.325, 0.843, 0.078)))

    filename = f"./tsne_plot_{label_disease_dictionary[actual_path[-5]]}"
    if epoch is not None:
        filename = filename + f"_{epoch}"
    filename = filename + name + ".png"
    plt.savefig(filename)

# %%
def label_def(row):
    if row['tuberculosis']==0 and row['hiv']==0:
        return 0
    elif row['tuberculosis']==1 and row['hiv']==0:
        return 1
    elif row['tuberculosis']==2 and row['hiv']==0:
        return 2
    elif row['tuberculosis']==0 and row['hiv']==1:
        return 3
    elif row['tuberculosis']==1 and row['hiv']==1:
        return 4
    elif row['tuberculosis']==2 and row['hiv']==1:
        return 5

label_disease_dictionary = dict()
label_disease_dictionary["0"] = "tuberculosis_0_hiv_0"
label_disease_dictionary["1"] = "tuberculosis_1_hiv_0"
label_disease_dictionary["2"] = "tuberculosis_2_hiv_0"
label_disease_dictionary["3"] = "tuberculosis_0_hiv_1"
label_disease_dictionary["4"] = "tuberculosis_1_hiv_1"
label_disease_dictionary["5"] = "tuberculosis_2_hiv_1"

# %% [markdown]
# # Data Processing

# %%
pca = PCA(0.9)

# %%
data = data.T

# %%
data
# Out:
#                                 0         1    ...        572         573
# 6247215025_L.AVG_Signal  119.645000  60.05559  ...  1543.5390   88.143910
# 6142077055_K.AVG_Signal  119.563500  78.60551  ...  1850.6630  101.974700
# 6142077060_J.AVG_Signal  123.213900  81.73999  ...  2091.1970   89.287840
# 6142077055_I.AVG_Signal  129.417000  59.07066  ...  2425.5130   80.197620
# 6142077060_K.AVG_Signal  105.425400  76.26342  ...  1848.8670   79.913120
# ...                             ...       ...  ...        ...         ...
# 5685521033_H.AVG_Signal   -2.189815 -46.03613  ...   536.7505  -18.575380
# 5685521033_I.AVG_Signal   25.470250 -42.13654  ...   716.7267    9.340691
# 5685521033_J.AVG_Signal    5.203332 -37.44641  ...   580.3944   -8.010675
# 5685521033_K.AVG_Signal  -11.847170 -48.77342  ...   509.8944  -22.590360
# 5685521033_L.AVG_Signal  -10.084410 -54.91108  ...   424.5071   -3.189697
#
# [1028 rows x 574 columns]

# %%
names = data.index.values
data.reset_index(drop=True, inplace=True)
data = pd.concat([data, pd.DataFrame(names, columns=["host_name"])], axis=1)

# %%
data.shape
# Out:
# (1028, 575)

# %%
classes['label'] = classes.apply(lambda x: label_def(x), axis=1)
data = pd.merge(data, classes, on='host_name')
data
# Out:
#              0         1          2  ...  tuberculosis  hiv  label
# 0    22.977790 -46.11452   3.379508  ...             1    0      1
# 1    24.390000 -49.27365   4.602244  ...             1    0      1
# 2    25.728400 -41.38828  23.113950  ...             1    1      4
# 3    40.313390 -45.15408  -7.856186  ...             1    1      4
# 4    21.593800 -46.83287  19.975260  ...             2    0      2
# ..         ...       ...        ...  ...           ...  ...    ...
# 532  -2.189815 -46.03613   5.749578  ...             2    1      5
# 533  25.470250 -42.13654  11.191050  ...             0    1      3
# 534   5.203332 -37.44641  -7.461519  ...             0    1      3
# 535 -11.847170 -48.77342  41.844610  ...             0    0      0
# 536 -10.084410 -54.91108  31.530910  ...             0    0      0
#
# [537 rows x 578 columns]

# %%
labels = list(set(data['label'].values))

# %%
datacl = data.drop(["tuberculosis", "hiv"], axis=1)
datacl.head()
# Out:
#           0         1          2  ...        573                host_name  label
# 0  22.97779 -46.11452   3.379508  ...   4.898625  5483347021_A.AVG_Signal      1
# 1  24.39000 -49.27365   4.602244  ... -13.996800  5483347021_B.AVG_Signal      1
# 2  25.72840 -41.38828  23.113950  ...   9.648779  5483347021_C.AVG_Signal      4
# 3  40.31339 -45.15408  -7.856186  ...  28.543990  5483347021_D.AVG_Signal      4
# 4  21.59380 -46.83287  19.975260  ...   9.005090  5483347021_E.AVG_Signal      2
#
# [5 rows x 576 columns]

# %% [markdown]
# # Multi Model Approach (Reduce After Split)

# %% [markdown]
# ## Model 0
#
# ### label = 0

# %%
# data_0 = datacl[datacl['label']==0]
# host_names_0 = data_0.host_name.values
# label = data_0.label.values
# data_0 = data_0.drop(["host_name", "label"], axis=1)
# data_0.head()
# data_0.shape
# # Perform PCA
# data_0 = pca.fit_transform(data_0)
# data_0 = pd.DataFrame(data_0)
# columns = list(data_0.columns.values)
# model0 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model0.fit(data_0, columns, epochs = 1000)
# samples1 = model0.sample(100)
# samples2 = model0.sample(50)
# samples3 = model0.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model0.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_0.to_csv("./data0.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data0.csv", f"_model_0_{sample.shape[0]}")

# %% [markdown]
# ## Model 1
#
# ### label 1

# %%
# data_1 = datacl[datacl['label']==1]
# host_names_1 = data_1.host_name.values
# label = data_1.label.values
# data_1 = data_1.drop(["host_name", "label"], axis=1)
# data_1.head()
# data_1.shape
# # Perform PCA
# data_1 = pca.fit_transform(data_1)
# data_1 = pd.DataFrame(data_1)
# columns = list(data_1.columns.values)
# model1 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model1.fit(data_1, columns, epochs = 1000)
# samples1 = model1.sample(100)
# samples2 = model1.sample(50)
# samples3 = model1.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model1.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_1.to_csv("./data1.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data1.csv", f"_model_1_{sample.shape[0]}")

# %% [markdown]
# ## Model 2
# ### label 2

# %%
# data_2 = datacl[datacl['label']==2]
# host_names_2 = data_2.host_name.values
# label = data_2.label.values
# data_2 = data_2.drop(["host_name", "label"], axis=1)
# data_2.head()
# data_2.shape
# # Perform PCA
# data_2 = pca.fit_transform(data_2)
# data_2 = pd.DataFrame(data_2)
# columns = list(data_2.columns.values)
# model2 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model2.fit(data_2, columns, epochs = 1000)
# samples1 = model2.sample(100)
# samples2 = model2.sample(50)
# samples3 = model2.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model2.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_2.to_csv("./data2.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data2.csv", f"_model_2_{sample.shape[0]}")

# %% [markdown]
# ## Model 3
# # label 3

# %%
# data_3 = datacl[datacl['label']==3]
# host_names_3 = data_3.host_name.values
# label = data_3.label.values
# data_3 = data_3.drop(["host_name", "label"], axis=1)
# data_3.head()
# data_3.shape
# # Perform PCA
# data_3 = pca.fit_transform(data_3)
# data_3 = pd.DataFrame(data_3)
# columns = list(data_3.columns.values)
# model3 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model3.fit(data_3, columns, epochs = 1000)
# samples1 = model3.sample(100)
# samples2 = model3.sample(50)
# samples3 = model3.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model3.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_3.to_csv("./data3.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data3.csv", f"_model_3_{sample.shape[0]}")

# %% [markdown]
# ## Model 4
#
# ### label 4

# %%
# data_4 = datacl[datacl['label']==4]
# host_names_4 = data_4.host_name.values
# label = data_4.label.values
# data_4 = data_4.drop(["host_name", "label"], axis=1)
# data_4.head()
# data_4.shape
# # Perform PCA
# data_4 = pca.fit_transform(data_4)
# data_4 = pd.DataFrame(data_4)
# columns = list(data_4.columns.values)
# model4 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model4.fit(data_4, columns, epochs = 1000)
# samples1 = model4.sample(100)
# samples2 = model4.sample(50)
# samples3 = model4.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model4.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_4.to_csv("./data4.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data4.csv", f"_model_4_{sample.shape[0]}")

# %% [markdown]
# ## Model 5
# ### label 5

# %%
# data_5 = datacl[datacl['label']==5]
# host_names_5 = data_5.host_name.values
# label = data_5.label.values
# data_5 = data_5.drop(["host_name", "label"], axis=1)
# data_5.head()
# data_5.shape
# # Perform PCA
# data_5 = pca.fit_transform(data_5)
# data_5 = pd.DataFrame(data_5)
# columns = list(data_5.columns.values)
# model5 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model5.fit(data_5, columns, epochs = 1000)
# samples1 = model5.sample(100)
# samples2 = model5.sample(50)
# samples3 = model5.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model5.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_5.to_csv("./data5.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data5.csv", f"_model_5_{sample.shape[0]}")

# %% [markdown]
# # Multi Model Approach (Reduce Before Split)

# %%
# host_names = datacl.host_name
# labels = datacl.label
# datacl = datacl.drop(["host_name", "label"], axis=1)
# data_reduced = pca.fit_transform(datacl)
# data_reduced = pd.DataFrame(data_reduced)
# data_reduced = pd.concat([data_reduced, host_names, labels], axis=1)
# data_reduced.head()

# %% [markdown]
# ## Model 0
# ### label 0

# %%
# data_0 = data_reduced[data_reduced['label']==0]
# host_names_0 = data_0.host_name.values
# label = data_0.label.values
# data_0 = data_0.drop(["host_name", "label"], axis=1)
# data_0.head()
# data_0.shape
# columns = list(data_0.columns.values)
# model0 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model0.fit(data_0, columns, epochs = 1000)
# samples1 = model0.sample(100)
# samples2 = model0.sample(50)
# samples3 = model0.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model0.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_0.to_csv("./data0.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data0.csv", f"_model_0_{sample.shape[0]}")

# %% [markdown]
# ## Model 1
# ### label 1

# %%
# data_1 = data_reduced[data_reduced['label']==1]
# host_names_1 = data_1.host_name.values
# label = data_1.label.values
# data_1 = data_1.drop(["host_name", "label"], axis=1)
# data_1.head()
# data_1.shape
# columns = list(data_1.columns.values)
# model1 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model1.fit(data_1, columns, epochs = 1000)
# samples1 = model1.sample(100)
# samples2 = model1.sample(50)
# samples3 = model1.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model1.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_1.to_csv("./data1.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data1.csv", f"_model_1_{sample.shape[0]}")

# %% [markdown]
# ## Model 2
# ### label 2

# %%
# data_2 = data_reduced[data_reduced['label']==2]
# host_names_2 = data_2.host_name.values
# label = data_2.label.values
# data_2 = data_2.drop(["host_name", "label"], axis=1)
# data_2.head()
# data_2.shape
# columns = list(data_2.columns.values)
# model2 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model2.fit(data_2, columns, epochs = 1000)
# samples1 = model2.sample(100)
# samples2 = model2.sample(50)
# samples3 = model2.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model2.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_2.to_csv("./data2.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data2.csv", f"_model_2_{sample.shape[0]}")

# %% [markdown]
# ## Model 3
# ### label 3

# %%
# data_3 = data_reduced[data_reduced['label']==3]
# host_names_3 = data_3.host_name.values
# label = data_3.label.values
# data_3 = data_3.drop(["host_name", "label"], axis=1)
# data_3.head()
# data_3.shape
# columns = list(data_3.columns.values)
# model3 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model3.fit(data_3, columns, epochs = 1000)
# samples1 = model3.sample(100)
# samples2 = model3.sample(50)
# samples3 = model3.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model3.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_3.to_csv("./data3.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data3.csv", f"_model_3_{sample.shape[0]}")

# %% [markdown]
# ## Model 4
# ### label 4

# %%
# data_4 = data_reduced[data_reduced['label']==4]
# host_names_4 = data_4.host_name.values
# label = data_4.label.values
# data_4 = data_4.drop(["host_name", "label"], axis=1)
# data_4.head()
# data_4.shape
# columns = list(data_4.columns.values)
# model4 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model4.fit(data_4, columns, epochs = 1000)
# samples1 = model4.sample(100)
# samples2 = model4.sample(50)
# samples3 = model4.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model4.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_4.to_csv("./data4.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data4.csv", f"_model_4_{sample.shape[0]}")

# %% [markdown]
# ## Model 5
# ### label 5

# %%
# data_5 = data_reduced[data_reduced['label']==5]
# host_names_5 = data_5.host_name.values
# label = data_5.label.values
# data_5 = data_5.drop(["host_name", "label"], axis=1)
# data_5.head()
# data_5.shape
# columns = list(data_5.columns.values)
# model5 = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
# model5.fit(data_5, columns, epochs = 1000)
# samples1 = model5.sample(100)
# samples2 = model5.sample(50)
# samples3 = model5.sample(150)

# for sample in [samples1, samples2, samples3]:
#     size = sample.shape[0]
#     name = f"./sample_{size}_model5.csv"
#     sample = pd.DataFrame(sample)
#     sample.to_csv(name)

# data_5.to_csv("./data5.csv")
# for sample in [samples1, samples2, samples3]:
#   sample.reset_index(drop=True, inplace=True)
#   plot_tsne(sample, "./data5.csv", f"_model_5_{sample.shape[0]}")

# %% [markdown]
# # Single Model Approach

# %%
host_names = datacl.host_name
labels = datacl.label
datacl = datacl.drop(["host_name", "label"], axis=1)
data_reduced = pca.fit_transform(datacl)
data_reduced = pd.DataFrame(data_reduced)
data_reduced = pd.concat([data_reduced, labels], axis=1)

# %%
columns = list(data_reduced.columns.values)
single_model = ctgan.CTGANSynthesizer(batch_size=10, gen_dim=(256, 256), dis_dim=(256, 256))
single_model.fit(data_reduced, columns, epochs = 1000)
samples1 = single_model.sample(100)
samples2 = single_model.sample(50)
samples3 = single_model.sample(150)

for sample in [samples1, samples2, samples3]:
    size = sample.shape[0]
    name = f"./sample_{size}_model0.csv"
    sample = pd.DataFrame(sample)
    sample.to_csv(name)

data_reduced.to_csv("./data_reduced.csv")

for sample in [samples1, samples2, samples3]:
    sample.reset_index(drop=True, inplace=True)
    plot_tsne(sample, "./data_reduced.csv", f"_single_model_{sample.shape[0]}")
# Out:
# Epoch 1, Loss G: 5.3704, Loss D: -0.0129
# Epoch 2, Loss G: 6.0373, Loss D: 0.0190
# Epoch 3, Loss G: 6.2596, Loss D: 0.0441
# Epoch 4, Loss G: 5.2957, Loss D: -0.0485
# Epoch 5, Loss G: 6.6037, Loss D: 0.1456
# Epoch 6, Loss G: 6.0941, Loss D: -0.1163
# Epoch 7, Loss G: 6.6973, Loss D: 0.0143
# Epoch 8, Loss G: 5.6214, Loss D: -0.0304
# Epoch 9, Loss G: 5.9446, Loss D: -0.1219
# Epoch 10, Loss G: 5.7318, Loss D: -0.0541
# Epoch 11, Loss G: 6.7497, Loss D: -0.0541
# Epoch 12, Loss G: 5.6045, Loss D: -0.2013
# Epoch 13, Loss G: 6.3807, Loss D: -0.0960
# Epoch 14, Loss G: 7.2708, Loss D: -0.1756
# Epoch 15, Loss G: 7.1211, Loss D: -0.0708
# Epoch 16, Loss G: 7.0056, Loss D: -0.1111
# Epoch 17, Loss G: 5.4749, Loss D: -0.2327
# Epoch 18, Loss G: 6.9754, Loss D: -0.2685
# Epoch 19, Loss G: 5.3179, Loss D: -0.1376
# Epoch 20, Loss G: 7.3985, Loss D: -0.1862
# Epoch 21, Loss G: 5.4182, Loss D: 0.0452
# Epoch 22, Loss G: 7.0432, Loss D: -0.0767
# Epoch 23, Loss G: 6.1908, Loss D: -0.0786
# Epoch 24, Loss G: 5.7463, Loss D: -0.3301
# Epoch 25, Loss G: 6.1413, Loss D: -0.1394
# Epoch 26, Loss G: 7.4142, Loss D: -0.1628
# Epoch 27, Loss G: 6.5646, Loss D: -0.1293
# Epoch 28, Loss G: 5.9393, Loss D: -0.1126
# Epoch 29, Loss G: 6.0099, Loss D: -0.1379
# Epoch 30, Loss G: 6.7460, Loss D: -0.0530
# Epoch 31, Loss G: 5.7348, Loss D: -0.1505
# Epoch 32, Loss G: 6.2509, Loss D: -0.1595
# Epoch 33, Loss G: 6.8384, Loss D: 0.1714
# Epoch 34, Loss G: 6.0198, Loss D: -0.0883
# Epoch 35, Loss G: 6.2529, Loss D: 0.1313
# Epoch 36, Loss G: 7.0150, Loss D: 0.0537
# Epoch 37, Loss G: 5.6808, Loss D: -0.1157
# Epoch 38, Loss G: 4.6617, Loss D: -0.2016
# Epoch 39, Loss G: 5.2504, Loss D: -0.0603
# Epoch 40, Loss G: 6.2929, Loss D: -0.1287
# Epoch 41, Loss G: 6.2346, Loss D: -0.0527
# Epoch 42, Loss G: 6.4900, Loss D: -0.1370
# Epoch 43, Loss G: 5.6191, Loss D: -0.1357
# Epoch 44, Loss G: 5.0395, Loss D: -0.1400
# Epoch 45, Loss G: 6.3689, Loss D: -0.0880
# Epoch 46, Loss G: 7.1967, Loss D: -0.1867
# Epoch 47, Loss G: 5.6735, Loss D: -0.0415
# Epoch 48, Loss G: 7.1678, Loss D: -0.0114
# Epoch 49, Loss G: 4.6725, Loss D: -0.0901
# Epoch 50, Loss G: 6.1667, Loss D: 0.1673
# Epoch 51, Loss G: 4.6316, Loss D: 0.0571
# Epoch 52, Loss G: 6.6750, Loss D: 0.1009
# Epoch 53, Loss G: 5.2871, Loss D: -0.1117
# Epoch 54, Loss G: 5.2585, Loss D: -0.0752
# Epoch 55, Loss G: 5.3894, Loss D: 0.0990
# Epoch 56, Loss G: 5.9289, Loss D: -0.0731
# Epoch 57, Loss G: 5.7920, Loss D: -0.1020
# Epoch 58, Loss G: 5.9946, Loss D: -0.0465
# Epoch 59, Loss G: 6.6073, Loss D: -0.0483
# Epoch 60, Loss G: 6.1724, Loss D: -0.1465
# Epoch 61, Loss G: 5.4230, Loss D: -0.0431
# Epoch 62, Loss G: 7.1307, Loss D: -0.0178
# Epoch 63, Loss G: 4.5580, Loss D: -0.1066
# Epoch 64, Loss G: 6.8585, Loss D: -0.0980
# Epoch 65, Loss G: 7.2326, Loss D: -0.0205
# Epoch 66, Loss G: 5.9190, Loss D: -0.2066
# Epoch 67, Loss G: 4.3942, Loss D: -0.0920
# Epoch 68, Loss G: 5.0561, Loss D: -0.1600
# Epoch 69, Loss G: 5.5158, Loss D: -0.0160
# Epoch 70, Loss G: 6.9800, Loss D: -0.1027
# Epoch 71, Loss G: 6.2008, Loss D: 0.0014
# Epoch 72, Loss G: 6.8608, Loss D: -0.1265
# Epoch 73, Loss G: 3.9737, Loss D: 0.0318
# Epoch 74, Loss G: 5.0794, Loss D: 0.0715
# Epoch 75, Loss G: 6.5814, Loss D: -0.0618
# Epoch 76, Loss G: 5.8512, Loss D: -0.0973
# Epoch 77, Loss G: 5.4041, Loss D: -0.2123
# Epoch 78, Loss G: 4.5261, Loss D: -0.1425
# Epoch 79, Loss G: 5.1952, Loss D: -0.0481
# Epoch 80, Loss G: 6.3352, Loss D: 0.0293
# Epoch 81, Loss G: 6.5869, Loss D: -0.0821
# Epoch 82, Loss G: 4.7348, Loss D: -0.1309
# Epoch 83, Loss G: 4.4345, Loss D: -0.0767
# Epoch 84, Loss G: 5.1906, Loss D: -0.0764
# Epoch 85, Loss G: 5.2844, Loss D: -0.3852
# Epoch 86, Loss G: 6.9300, Loss D: 0.0846
# Epoch 87, Loss G: 5.2964, Loss D: -0.1880
# Epoch 88, Loss G: 5.9377, Loss D: -0.0796
# Epoch 89, Loss G: 5.4103, Loss D: 0.0026
# Epoch 90, Loss G: 5.1119, Loss D: -0.1169
# Epoch 91, Loss G: 5.8196, Loss D: 0.1039
# Epoch 92, Loss G: 5.7820, Loss D: -0.1417
# Epoch 93, Loss G: 6.7828, Loss D: -0.1624
# Epoch 94, Loss G: 4.5557, Loss D: -0.0746
# Epoch 95, Loss G: 5.8057, Loss D: 0.0020
# Epoch 96, Loss G: 5.9133, Loss D: -0.0693
# Epoch 97, Loss G: 6.6214, Loss D: 0.1601
# Epoch 98, Loss G: 5.9970, Loss D: -0.1579
# Epoch 99, Loss G: 5.8862, Loss D: -0.2727
# Epoch 100, Loss G: 6.5865, Loss D: -0.0926
# Epoch 101, Loss G: 6.6099, Loss D: -0.1029
# Epoch 102, Loss G: 4.4607, Loss D: 0.1430
# Epoch 103, Loss G: 6.5131, Loss D: 0.1279
# Epoch 104, Loss G: 5.2903, Loss D: -0.0585
# Epoch 105, Loss G: 4.0503, Loss D: -0.1363
# Epoch 106, Loss G: 5.7782, Loss D: -0.0926
# Epoch 107, Loss G: 5.7588, Loss D: 0.0075
# Epoch 108, Loss G: 6.4669, Loss D: -0.3559
# Epoch 109, Loss G: 5.8874, Loss D: -0.2354
# Epoch 110, Loss G: 5.8567, Loss D: 0.1134
# Epoch 111, Loss G: 5.7884, Loss D: 0.0205
# Epoch 112, Loss G: 6.5327, Loss D: -0.2531
# Epoch 113, Loss G: 5.7733, Loss D: -0.0828
# Epoch 114, Loss G: 6.5021, Loss D: 0.0868
# Epoch 115, Loss G: 5.2864, Loss D: -0.0576
# Epoch 116, Loss G: 5.6975, Loss D: -0.0269
# Epoch 117, Loss G: 6.2970, Loss D: -0.0512
# Epoch 118, Loss G: 5.2915, Loss D: -0.1089
# Epoch 119, Loss G: 6.4845, Loss D: -0.1149
# Epoch 120, Loss G: 5.2585, Loss D: -0.0467
# Epoch 121, Loss G: 5.6692, Loss D: -0.0767
# Epoch 122, Loss G: 5.8216, Loss D: 0.0444
# Epoch 123, Loss G: 5.7485, Loss D: 0.0296
# Epoch 124, Loss G: 6.3630, Loss D: -0.0433
# Epoch 125, Loss G: 6.4538, Loss D: -0.0001
# Epoch 126, Loss G: 3.9609, Loss D: -0.0699
# Epoch 127, Loss G: 5.8055, Loss D: 0.0002
# Epoch 128, Loss G: 5.8095, Loss D: 0.0602
# Epoch 129, Loss G: 5.7630, Loss D: -0.2816
# Epoch 130, Loss G: 4.5799, Loss D: -0.0555
# Epoch 131, Loss G: 6.4229, Loss D: -0.1155
# Epoch 132, Loss G: 5.8369, Loss D: -0.1341
# Epoch 133, Loss G: 6.3325, Loss D: -0.0183
# Epoch 134, Loss G: 5.1549, Loss D: 0.1187
# Epoch 135, Loss G: 5.7181, Loss D: -0.1765
# Epoch 136, Loss G: 6.3216, Loss D: -0.1119
# Epoch 137, Loss G: 6.3360, Loss D: 0.0660
# Epoch 138, Loss G: 4.3907, Loss D: 0.0514
# Epoch 139, Loss G: 6.3640, Loss D: -0.0818
# Epoch 140, Loss G: 5.2997, Loss D: -0.0391
# Epoch 141, Loss G: 6.2934, Loss D: -0.0396
# Epoch 142, Loss G: 6.3365, Loss D: -0.1333
# Epoch 143, Loss G: 6.4005, Loss D: -0.0612
# Epoch 144, Loss G: 3.8913, Loss D: -0.1389
# Epoch 145, Loss G: 6.3946, Loss D: -0.0602
# Epoch 146, Loss G: 5.7978, Loss D: -0.0756
# Epoch 147, Loss G: 5.1164, Loss D: -0.0751
# Epoch 148, Loss G: 6.4725, Loss D: -0.1217
# Epoch 149, Loss G: 5.1398, Loss D: -0.0496
# Epoch 150, Loss G: 5.7400, Loss D: 0.1037
# Epoch 151, Loss G: 6.2523, Loss D: -0.1773
# Epoch 152, Loss G: 5.8394, Loss D: -0.0052
# Epoch 153, Loss G: 6.3854, Loss D: -0.0200
# Epoch 154, Loss G: 5.1688, Loss D: 0.1633
# Epoch 155, Loss G: 5.1581, Loss D: 0.0537
# Epoch 156, Loss G: 5.7045, Loss D: -0.2631
# Epoch 157, Loss G: 5.6952, Loss D: -0.0368
# Epoch 158, Loss G: 5.0303, Loss D: 0.0827
# Epoch 159, Loss G: 4.5735, Loss D: 0.1405
# Epoch 160, Loss G: 6.4552, Loss D: -0.0033
# Epoch 161, Loss G: 6.4675, Loss D: -0.1555
# Epoch 162, Loss G: 3.8695, Loss D: 0.0542
# Epoch 163, Loss G: 5.6568, Loss D: -0.1104
# Epoch 164, Loss G: 6.4287, Loss D: -0.0876
# Epoch 165, Loss G: 5.7998, Loss D: 0.1356
# Epoch 166, Loss G: 4.9586, Loss D: 0.0600
# Epoch 167, Loss G: 6.3712, Loss D: 0.0695
# Epoch 168, Loss G: 4.5239, Loss D: 0.1183
# Epoch 169, Loss G: 6.3903, Loss D: -0.0224
# Epoch 170, Loss G: 5.6421, Loss D: -0.0055
# Epoch 171, Loss G: 6.3406, Loss D: -0.0549
# Epoch 172, Loss G: 5.7297, Loss D: -0.0334
# Epoch 173, Loss G: 4.9965, Loss D: -0.1233
# Epoch 174, Loss G: 5.6602, Loss D: 0.0546
# Epoch 175, Loss G: 5.7627, Loss D: -0.2125
# Epoch 176, Loss G: 6.5191, Loss D: 0.1533
# Epoch 177, Loss G: 5.2827, Loss D: 0.0008
# Epoch 178, Loss G: 5.7194, Loss D: -0.0166
# Epoch 179, Loss G: 5.8121, Loss D: 0.0739
# Epoch 180, Loss G: 5.8994, Loss D: -0.1632
# Epoch 181, Loss G: 5.6991, Loss D: 0.2250
# Epoch 182, Loss G: 5.7414, Loss D: -0.0501
# Epoch 183, Loss G: 3.9393, Loss D: 0.1815
# Epoch 184, Loss G: 6.5737, Loss D: -0.0866
# Epoch 185, Loss G: 6.3942, Loss D: -0.1793
# Epoch 186, Loss G: 5.7243, Loss D: -0.0506
# Epoch 187, Loss G: 6.3890, Loss D: -0.0118
# Epoch 188, Loss G: 5.6431, Loss D: -0.0299
# Epoch 189, Loss G: 4.5536, Loss D: -0.0063
# Epoch 190, Loss G: 5.7902, Loss D: 0.0018
# Epoch 191, Loss G: 5.2255, Loss D: 0.0336
# Epoch 192, Loss G: 5.9302, Loss D: -0.1401
# Epoch 193, Loss G: 5.6796, Loss D: -0.0760
# Epoch 194, Loss G: 5.7725, Loss D: 0.0295
# Epoch 195, Loss G: 4.5562, Loss D: 0.1989
# Epoch 196, Loss G: 6.4448, Loss D: -0.0766
# Epoch 197, Loss G: 6.3459, Loss D: -0.1182
# Epoch 198, Loss G: 5.8235, Loss D: -0.1440
# Epoch 199, Loss G: 5.8513, Loss D: -0.0544
# Epoch 200, Loss G: 5.8519, Loss D: -0.0166
# Epoch 201, Loss G: 6.4256, Loss D: 0.0120
# Epoch 202, Loss G: 6.4378, Loss D: -0.2015
# Epoch 203, Loss G: 6.4459, Loss D: -0.0952
# Epoch 204, Loss G: 5.8030, Loss D: -0.1550
# Epoch 205, Loss G: 5.7654, Loss D: 0.0279
# Epoch 206, Loss G: 6.4140, Loss D: -0.1827
# Epoch 207, Loss G: 5.9700, Loss D: 0.0085
# Epoch 208, Loss G: 5.7990, Loss D: 0.1459
# Epoch 209, Loss G: 5.8118, Loss D: -0.0227
# Epoch 210, Loss G: 6.3342, Loss D: -0.0153
# Epoch 211, Loss G: 5.2422, Loss D: -0.1061
# Epoch 212, Loss G: 5.1904, Loss D: -0.0302
# Epoch 213, Loss G: 5.7517, Loss D: 0.1161
# Epoch 214, Loss G: 5.1630, Loss D: -0.0506
# Epoch 215, Loss G: 5.0463, Loss D: -0.0271
# Epoch 216, Loss G: 6.4388, Loss D: -0.0448
# Epoch 217, Loss G: 5.8879, Loss D: -0.0082
# Epoch 218, Loss G: 6.5108, Loss D: 0.0804
# Epoch 219, Loss G: 5.7324, Loss D: 0.0843
# Epoch 220, Loss G: 5.8712, Loss D: 0.1109
# Epoch 221, Loss G: 5.8333, Loss D: -0.0000
# Epoch 222, Loss G: 6.6453, Loss D: 0.1576
# Epoch 223, Loss G: 5.0238, Loss D: 0.0220
# Epoch 224, Loss G: 4.5018, Loss D: -0.0221
# Epoch 225, Loss G: 5.0791, Loss D: 0.0563
# Epoch 226, Loss G: 5.8345, Loss D: -0.1406
# Epoch 227, Loss G: 5.8550, Loss D: -0.0317
# Epoch 228, Loss G: 6.5631, Loss D: -0.0458
# Epoch 229, Loss G: 5.8807, Loss D: 0.0685
# Epoch 230, Loss G: 5.9599, Loss D: -0.1968
# Epoch 231, Loss G: 5.2009, Loss D: -0.1675
# Epoch 232, Loss G: 5.9055, Loss D: 0.1513
# Epoch 233, Loss G: 5.8186, Loss D: 0.0019
# Epoch 234, Loss G: 5.2740, Loss D: -0.1180
# Epoch 235, Loss G: 5.2181, Loss D: 0.0753
# Epoch 236, Loss G: 5.9183, Loss D: -0.0723
# Epoch 237, Loss G: 5.9043, Loss D: 0.1460
# Epoch 238, Loss G: 6.4355, Loss D: 0.0427
# Epoch 239, Loss G: 5.7708, Loss D: -0.2062
# Epoch 240, Loss G: 5.2173, Loss D: -0.0041
# Epoch 241, Loss G: 5.9995, Loss D: 0.2237
# Epoch 242, Loss G: 5.3029, Loss D: -0.0997
# Epoch 243, Loss G: 6.5824, Loss D: 0.1441
# Epoch 244, Loss G: 6.4950, Loss D: -0.0915
# Epoch 245, Loss G: 6.4657, Loss D: -0.0299
# Epoch 246, Loss G: 5.3302, Loss D: -0.0727
# Epoch 247, Loss G: 4.4661, Loss D: -0.2065
# Epoch 248, Loss G: 5.2788, Loss D: -0.0576
# Epoch 249, Loss G: 6.5001, Loss D: 0.1497
# Epoch 250, Loss G: 5.2894, Loss D: -0.1665
# Epoch 251, Loss G: 6.5143, Loss D: -0.0642
# Epoch 252, Loss G: 4.6284, Loss D: 0.0261
# Epoch 253, Loss G: 5.9169, Loss D: 0.1007
# Epoch 254, Loss G: 6.6421, Loss D: 0.1652
# Epoch 255, Loss G: 5.8828, Loss D: -0.2119
# Epoch 256, Loss G: 5.8238, Loss D: 0.0068
# Epoch 257, Loss G: 5.1411, Loss D: 0.1658
# Epoch 258, Loss G: 5.1395, Loss D: -0.1415
# Epoch 259, Loss G: 5.9694, Loss D: -0.1213
# Epoch 260, Loss G: 6.3890, Loss D: 0.2007
# Epoch 261, Loss G: 6.5541, Loss D: -0.1037
# Epoch 262, Loss G: 5.2204, Loss D: 0.2852
# Epoch 263, Loss G: 5.9158, Loss D: -0.0033
# Epoch 264, Loss G: 6.5450, Loss D: -0.1196
# Epoch 265, Loss G: 5.1446, Loss D: -0.2698
# Epoch 266, Loss G: 5.2208, Loss D: -0.0957
# Epoch 267, Loss G: 6.3173, Loss D: 0.1232
# Epoch 268, Loss G: 4.5306, Loss D: -0.1668
# Epoch 269, Loss G: 5.2353, Loss D: -0.1588
# Epoch 270, Loss G: 6.5327, Loss D: -0.1422
# Epoch 271, Loss G: 5.7504, Loss D: -0.0099
# Epoch 272, Loss G: 5.8811, Loss D: -0.0542
# Epoch 273, Loss G: 5.9672, Loss D: 0.0959
# Epoch 274, Loss G: 5.8592, Loss D: -0.2337
# Epoch 275, Loss G: 5.9118, Loss D: -0.1622
# Epoch 276, Loss G: 5.0889, Loss D: -0.0887
# Epoch 277, Loss G: 6.3190, Loss D: 0.1044
# Epoch 278, Loss G: 5.1331, Loss D: -0.0630
# Epoch 279, Loss G: 5.1305, Loss D: -0.0981
# Epoch 280, Loss G: 5.8745, Loss D: -0.0633
# Epoch 281, Loss G: 5.1840, Loss D: 0.0007
# Epoch 282, Loss G: 6.5537, Loss D: 0.0538
# Epoch 283, Loss G: 4.6675, Loss D: 0.0286
# Epoch 284, Loss G: 5.9116, Loss D: -0.0751
# Epoch 285, Loss G: 5.8459, Loss D: -0.1182
# Epoch 286, Loss G: 5.8958, Loss D: -0.1806
# Epoch 287, Loss G: 4.6669, Loss D: 0.0632
# Epoch 288, Loss G: 5.8647, Loss D: 0.1460
# Epoch 289, Loss G: 5.6876, Loss D: 0.0112
# Epoch 290, Loss G: 5.8927, Loss D: -0.0497
# Epoch 291, Loss G: 5.7428, Loss D: 0.0050
# Epoch 292, Loss G: 5.4166, Loss D: 0.1665
# Epoch 293, Loss G: 5.7967, Loss D: 0.0071
# Epoch 294, Loss G: 6.4564, Loss D: -0.0598
# Epoch 295, Loss G: 3.8588, Loss D: 0.0843
# Epoch 296, Loss G: 5.1087, Loss D: -0.0922
# Epoch 297, Loss G: 6.6376, Loss D: -0.0068
# Epoch 298, Loss G: 5.7378, Loss D: -0.0300
# Epoch 299, Loss G: 5.7788, Loss D: 0.0334
# Epoch 300, Loss G: 6.3853, Loss D: -0.0139
# Epoch 301, Loss G: 6.4519, Loss D: -0.1323
# Epoch 302, Loss G: 5.6953, Loss D: -0.1363
# Epoch 303, Loss G: 5.8862, Loss D: -0.1878
# Epoch 304, Loss G: 4.6289, Loss D: -0.0643
# Epoch 305, Loss G: 5.3329, Loss D: -0.0154
# Epoch 306, Loss G: 5.3071, Loss D: 0.0482
# Epoch 307, Loss G: 5.8833, Loss D: -0.0726
# Epoch 308, Loss G: 5.9255, Loss D: 0.1421
# Epoch 309, Loss G: 4.5991, Loss D: -0.0327
# Epoch 310, Loss G: 5.6601, Loss D: 0.0304
# Epoch 311, Loss G: 5.8172, Loss D: 0.0683
# Epoch 312, Loss G: 4.6460, Loss D: -0.0519
# Epoch 313, Loss G: 6.2991, Loss D: 0.0237
# Epoch 314, Loss G: 6.3735, Loss D: 0.0478
# Epoch 315, Loss G: 6.4319, Loss D: 0.0848
# Epoch 316, Loss G: 5.1675, Loss D: -0.0032
# Epoch 317, Loss G: 5.2161, Loss D: -0.0466
# Epoch 318, Loss G: 5.1344, Loss D: -0.1258
# Epoch 319, Loss G: 5.8727, Loss D: -0.0100
# Epoch 320, Loss G: 5.9033, Loss D: -0.0187
# Epoch 321, Loss G: 5.1158, Loss D: -0.0173
# Epoch 322, Loss G: 5.1305, Loss D: -0.3477
# Epoch 323, Loss G: 5.7660, Loss D: -0.0012
# Epoch 324, Loss G: 5.7216, Loss D: -0.0622
# Epoch 325, Loss G: 5.6833, Loss D: -0.0267
# Epoch 326, Loss G: 5.8318, Loss D: -0.0505
# Epoch 327, Loss G: 5.2593, Loss D: 0.0777
# Epoch 328, Loss G: 6.4437, Loss D: -0.0227
# Epoch 329, Loss G: 5.8721, Loss D: 0.0735
# Epoch 330, Loss G: 6.4373, Loss D: -0.0437
# Epoch 331, Loss G: 6.4250, Loss D: -0.2305
# Epoch 332, Loss G: 6.5088, Loss D: 0.0249
# Epoch 333, Loss G: 5.1374, Loss D: -0.1072
# Epoch 334, Loss G: 5.6562, Loss D: 0.2022
# Epoch 335, Loss G: 5.8713, Loss D: -0.0888
# Epoch 336, Loss G: 5.9293, Loss D: 0.0702
# Epoch 337, Loss G: 5.7722, Loss D: 0.1456
# Epoch 338, Loss G: 4.6174, Loss D: 0.1727
# Epoch 339, Loss G: 4.5262, Loss D: 0.0597
# Epoch 340, Loss G: 6.3436, Loss D: -0.0356
# Epoch 341, Loss G: 6.4710, Loss D: 0.1318
# Epoch 342, Loss G: 6.4876, Loss D: -0.1730
# Epoch 343, Loss G: 5.8900, Loss D: -0.0725
# Epoch 344, Loss G: 6.4833, Loss D: 0.1069
# Epoch 345, Loss G: 5.7438, Loss D: -0.0390
# Epoch 346, Loss G: 6.4742, Loss D: 0.1437
# Epoch 347, Loss G: 6.3410, Loss D: 0.0283
# Epoch 348, Loss G: 5.8185, Loss D: 0.1555
# Epoch 349, Loss G: 6.4090, Loss D: 0.1904
# Epoch 350, Loss G: 5.1832, Loss D: -0.0133
# Epoch 351, Loss G: 5.8096, Loss D: 0.1733
# Epoch 352, Loss G: 5.9712, Loss D: 0.0894
# Epoch 353, Loss G: 6.5652, Loss D: -0.1009
# Epoch 354, Loss G: 5.8965, Loss D: -0.2011
# Epoch 355, Loss G: 5.9396, Loss D: -0.0625
# Epoch 356, Loss G: 5.7440, Loss D: -0.0882
# Epoch 357, Loss G: 5.7947, Loss D: -0.0786
# Epoch 358, Loss G: 5.8178, Loss D: -0.0500
# Epoch 359, Loss G: 5.9316, Loss D: -0.0896
# Epoch 360, Loss G: 5.7454, Loss D: -0.1326
# Epoch 361, Loss G: 5.6906, Loss D: 0.0280
# Epoch 362, Loss G: 5.0942, Loss D: -0.0288
# Epoch 363, Loss G: 5.8733, Loss D: 0.0760
# Epoch 364, Loss G: 5.6202, Loss D: -0.0046
# Epoch 365, Loss G: 6.5431, Loss D: -0.0786
# Epoch 366, Loss G: 5.6522, Loss D: -0.0823
# Epoch 367, Loss G: 5.7019, Loss D: 0.1437
# Epoch 368, Loss G: 6.2160, Loss D: -0.1693
# Epoch 369, Loss G: 6.4836, Loss D: 0.1678
# Epoch 370, Loss G: 6.4060, Loss D: -0.1049
# Epoch 371, Loss G: 4.5066, Loss D: 0.2778
# Epoch 372, Loss G: 5.0303, Loss D: -0.0280
# Epoch 373, Loss G: 6.3584, Loss D: 0.1163
# Epoch 374, Loss G: 6.4381, Loss D: 0.0184
# Epoch 375, Loss G: 4.6173, Loss D: -0.0646
# Epoch 376, Loss G: 6.5058, Loss D: -0.1223
# Epoch 377, Loss G: 4.5511, Loss D: -0.3121
# Epoch 378, Loss G: 5.8423, Loss D: -0.0089
# Epoch 379, Loss G: 6.5875, Loss D: -0.2128
# Epoch 380, Loss G: 6.4305, Loss D: -0.1138
# Epoch 381, Loss G: 6.3848, Loss D: 0.1095
# Epoch 382, Loss G: 6.5618, Loss D: -0.2842
# Epoch 383, Loss G: 6.3813, Loss D: 0.0009
# Epoch 384, Loss G: 6.4054, Loss D: 0.0123
# Epoch 385, Loss G: 5.8367, Loss D: -0.0479
# Epoch 386, Loss G: 6.4923, Loss D: 0.0878
# Epoch 387, Loss G: 4.5793, Loss D: -0.0375
# Epoch 388, Loss G: 6.4145, Loss D: 0.1552
# Epoch 389, Loss G: 6.4315, Loss D: 0.1600
# Epoch 390, Loss G: 6.4478, Loss D: -0.3213
# Epoch 391, Loss G: 5.3611, Loss D: -0.0206
# Epoch 392, Loss G: 5.7939, Loss D: -0.0883
# Epoch 393, Loss G: 5.7907, Loss D: 0.2820
# Epoch 394, Loss G: 5.9008, Loss D: 0.1398
# Epoch 395, Loss G: 6.4408, Loss D: -0.1600
# Epoch 396, Loss G: 5.7129, Loss D: -0.0635
# Epoch 397, Loss G: 5.8570, Loss D: -0.0148
# Epoch 398, Loss G: 4.5816, Loss D: 0.2981
# Epoch 399, Loss G: 4.7046, Loss D: 0.0590
# Epoch 400, Loss G: 5.1926, Loss D: -0.0429
# Epoch 401, Loss G: 5.9334, Loss D: 0.0819
# Epoch 402, Loss G: 5.8952, Loss D: -0.1889
# Epoch 403, Loss G: 5.7970, Loss D: 0.0664
# Epoch 404, Loss G: 5.8015, Loss D: -0.1288
# Epoch 405, Loss G: 5.3001, Loss D: 0.0068
# Epoch 406, Loss G: 5.7521, Loss D: 0.0977
# Epoch 407, Loss G: 6.6096, Loss D: 0.0655
# Epoch 408, Loss G: 5.2186, Loss D: 0.0674
# Epoch 409, Loss G: 5.1815, Loss D: -0.1409
# Epoch 410, Loss G: 6.5686, Loss D: -0.1575
# Epoch 411, Loss G: 6.5273, Loss D: 0.1605
# Epoch 412, Loss G: 5.2680, Loss D: -0.1931
# Epoch 413, Loss G: 6.4014, Loss D: 0.0841
# Epoch 414, Loss G: 6.4093, Loss D: 0.1705
# Epoch 415, Loss G: 6.4720, Loss D: 0.0739
# Epoch 416, Loss G: 5.8695, Loss D: -0.2005
# Epoch 417, Loss G: 4.4885, Loss D: -0.0840
# Epoch 418, Loss G: 5.7399, Loss D: 0.0442
# Epoch 419, Loss G: 5.7573, Loss D: -0.0530
# Epoch 420, Loss G: 4.6388, Loss D: 0.0987
# Epoch 421, Loss G: 6.3461, Loss D: 0.0018
# Epoch 422, Loss G: 4.4837, Loss D: -0.0180
# Epoch 423, Loss G: 6.5515, Loss D: 0.0006
# Epoch 424, Loss G: 4.6854, Loss D: 0.0824
# Epoch 425, Loss G: 6.3915, Loss D: -0.0218
# Epoch 426, Loss G: 5.3413, Loss D: 0.0822
# Epoch 427, Loss G: 6.5484, Loss D: -0.1684
# Epoch 428, Loss G: 6.5070, Loss D: 0.0090
# Epoch 429, Loss G: 5.9278, Loss D: -0.0201
# Epoch 430, Loss G: 5.6917, Loss D: 0.1378
# Epoch 431, Loss G: 5.2734, Loss D: 0.1218
# Epoch 432, Loss G: 6.4149, Loss D: -0.2345
# Epoch 433, Loss G: 6.6144, Loss D: -0.1549
# Epoch 434, Loss G: 6.6586, Loss D: -0.0133
# Epoch 435, Loss G: 5.2011, Loss D: 0.1246
# Epoch 436, Loss G: 5.7675, Loss D: -0.0496
# Epoch 437, Loss G: 5.6482, Loss D: 0.0237
# Epoch 438, Loss G: 5.7619, Loss D: -0.0284
# Epoch 439, Loss G: 5.7165, Loss D: 0.0006
# Epoch 440, Loss G: 5.2025, Loss D: -0.0853
# Epoch 441, Loss G: 5.8664, Loss D: -0.0370
# Epoch 442, Loss G: 5.1216, Loss D: 0.0727
# Epoch 443, Loss G: 6.3368, Loss D: 0.0495
# Epoch 444, Loss G: 5.8286, Loss D: -0.1913
# Epoch 445, Loss G: 5.6237, Loss D: 0.0863
# Epoch 446, Loss G: 5.6027, Loss D: 0.1162
# Epoch 447, Loss G: 5.0770, Loss D: 0.1432
# Epoch 448, Loss G: 6.4936, Loss D: -0.0729
# Epoch 449, Loss G: 6.4743, Loss D: -0.1324
# Epoch 450, Loss G: 6.4083, Loss D: 0.0208
# Epoch 451, Loss G: 5.0155, Loss D: 0.0136
# Epoch 452, Loss G: 5.1900, Loss D: 0.2466
# Epoch 453, Loss G: 5.8907, Loss D: -0.0652
# Epoch 454, Loss G: 5.1746, Loss D: -0.1308
# Epoch 455, Loss G: 4.4995, Loss D: -0.1883
# Epoch 456, Loss G: 6.3055, Loss D: -0.0793
# Epoch 457, Loss G: 5.8174, Loss D: -0.0799
# Epoch 458, Loss G: 5.0928, Loss D: -0.0192
# Epoch 459, Loss G: 6.4334, Loss D: 0.2620
# Epoch 460, Loss G: 4.5733, Loss D: -0.0197
# Epoch 461, Loss G: 5.7883, Loss D: -0.2022
# Epoch 462, Loss G: 5.1598, Loss D: -0.0071
# Epoch 463, Loss G: 5.7426, Loss D: -0.1026
# Epoch 464, Loss G: 5.5952, Loss D: -0.1023
# Epoch 465, Loss G: 6.3791, Loss D: -0.1239
# Epoch 466, Loss G: 6.4540, Loss D: -0.0050
# Epoch 467, Loss G: 5.1512, Loss D: 0.0168
# Epoch 468, Loss G: 5.6815, Loss D: 0.1563
# Epoch 469, Loss G: 3.3278, Loss D: -0.0944
# Epoch 470, Loss G: 6.4381, Loss D: 0.2747
# Epoch 471, Loss G: 4.4842, Loss D: -0.0548
# Epoch 472, Loss G: 6.5310, Loss D: -0.0387
# Epoch 473, Loss G: 5.8400, Loss D: 0.0206
# Epoch 474, Loss G: 6.4966, Loss D: -0.1424
# Epoch 475, Loss G: 5.7563, Loss D: -0.0222
# Epoch 476, Loss G: 5.6335, Loss D: 0.0573
# Epoch 477, Loss G: 5.0819, Loss D: 0.1352
# Epoch 478, Loss G: 5.6874, Loss D: 0.0084
# Epoch 479, Loss G: 5.8956, Loss D: 0.0299
# Epoch 480, Loss G: 5.1388, Loss D: -0.0020
# Epoch 481, Loss G: 5.8349, Loss D: 0.1234
# Epoch 482, Loss G: 4.5341, Loss D: 0.1084
# Epoch 483, Loss G: 6.4614, Loss D: -0.0319
# Epoch 484, Loss G: 5.7970, Loss D: 0.1448
# Epoch 485, Loss G: 5.8326, Loss D: 0.0723
# Epoch 486, Loss G: 6.4779, Loss D: 0.3379
# Epoch 487, Loss G: 5.6234, Loss D: -0.0249
# Epoch 488, Loss G: 5.7776, Loss D: -0.3392
# Epoch 489, Loss G: 5.8694, Loss D: 0.0412
# Epoch 490, Loss G: 5.0618, Loss D: -0.0963
# Epoch 491, Loss G: 5.6435, Loss D: 0.1182
# Epoch 492, Loss G: 6.4082, Loss D: 0.2033
# Epoch 493, Loss G: 5.7856, Loss D: -0.2709
# Epoch 494, Loss G: 6.2533, Loss D: -0.0416
# Epoch 495, Loss G: 5.7421, Loss D: -0.0209
# Epoch 496, Loss G: 5.2430, Loss D: 0.2412
# Epoch 497, Loss G: 5.6457, Loss D: -0.2891
# Epoch 498, Loss G: 6.4033, Loss D: 0.2389
# Epoch 499, Loss G: 6.3422, Loss D: 0.1278
# Epoch 500, Loss G: 5.8274, Loss D: -0.0032
# Epoch 501, Loss G: 5.6799, Loss D: 0.0098
# Epoch 502, Loss G: 5.7570, Loss D: -0.0355
# Epoch 503, Loss G: 5.2001, Loss D: 0.1082
# Epoch 504, Loss G: 5.1291, Loss D: -0.0585
# Epoch 505, Loss G: 6.5094, Loss D: -0.0579
# Epoch 506, Loss G: 6.5420, Loss D: -0.2110
# Epoch 507, Loss G: 5.6140, Loss D: -0.1334
# Epoch 508, Loss G: 5.5828, Loss D: 0.0083
# Epoch 509, Loss G: 5.6968, Loss D: 0.0220
# Epoch 510, Loss G: 6.0593, Loss D: 0.0316
# Epoch 511, Loss G: 6.4188, Loss D: -0.0419
# Epoch 512, Loss G: 6.5135, Loss D: 0.0333
# Epoch 513, Loss G: 6.3144, Loss D: -0.0414
# Epoch 514, Loss G: 5.7258, Loss D: -0.1476
# Epoch 515, Loss G: 6.5064, Loss D: -0.0133
# Epoch 516, Loss G: 6.2873, Loss D: 0.0840
# Epoch 517, Loss G: 6.4564, Loss D: -0.2219
# Epoch 518, Loss G: 5.8857, Loss D: 0.1312
# Epoch 519, Loss G: 3.7894, Loss D: -0.2539
# Epoch 520, Loss G: 6.3299, Loss D: 0.1372
# Epoch 521, Loss G: 5.9224, Loss D: -0.0819
# Epoch 522, Loss G: 5.7285, Loss D: 0.0095
# Epoch 523, Loss G: 5.1204, Loss D: 0.1245
# Epoch 524, Loss G: 5.2702, Loss D: -0.0921
# Epoch 525, Loss G: 6.4008, Loss D: -0.0305
# Epoch 526, Loss G: 5.0385, Loss D: 0.0118
# Epoch 527, Loss G: 5.8300, Loss D: -0.2068
# Epoch 528, Loss G: 5.7055, Loss D: 0.0166
# Epoch 529, Loss G: 6.4397, Loss D: 0.1069
# Epoch 530, Loss G: 4.9666, Loss D: -0.0134
# Epoch 531, Loss G: 6.3411, Loss D: -0.0935
# Epoch 532, Loss G: 5.0546, Loss D: -0.0556
# Epoch 533, Loss G: 5.6870, Loss D: 0.0354
# Epoch 534, Loss G: 5.1331, Loss D: 0.0596
# Epoch 535, Loss G: 6.3134, Loss D: -0.0752
# Epoch 536, Loss G: 4.4773, Loss D: -0.0586
# Epoch 537, Loss G: 5.7795, Loss D: 0.1884
# Epoch 538, Loss G: 5.6976, Loss D: -0.0365
# Epoch 539, Loss G: 5.1993, Loss D: -0.1340
# Epoch 540, Loss G: 6.2851, Loss D: -0.0359
# Epoch 541, Loss G: 5.7862, Loss D: -0.1436
# Epoch 542, Loss G: 6.3420, Loss D: -0.2472
# Epoch 543, Loss G: 4.5170, Loss D: -0.0116
# Epoch 544, Loss G: 5.7163, Loss D: -0.1298
# Epoch 545, Loss G: 6.3810, Loss D: -0.1249
# Epoch 546, Loss G: 5.7862, Loss D: -0.0248
# Epoch 547, Loss G: 5.1750, Loss D: 0.0550
# Epoch 548, Loss G: 6.4563, Loss D: -0.0240
# Epoch 549, Loss G: 5.7578, Loss D: -0.1391
# Epoch 550, Loss G: 5.8674, Loss D: -0.0406
# Epoch 551, Loss G: 4.5418, Loss D: 0.0462
# Epoch 552, Loss G: 5.7034, Loss D: 0.0622
# Epoch 553, Loss G: 6.4127, Loss D: 0.0802
# Epoch 554, Loss G: 5.7342, Loss D: 0.1342
# Epoch 555, Loss G: 5.1356, Loss D: -0.0595
# Epoch 556, Loss G: 6.3883, Loss D: 0.0376
# Epoch 557, Loss G: 5.1144, Loss D: -0.0469
# Epoch 558, Loss G: 6.3743, Loss D: 0.1137
# Epoch 559, Loss G: 5.7325, Loss D: -0.0916
# Epoch 560, Loss G: 5.0712, Loss D: -0.0959
# Epoch 561, Loss G: 5.2167, Loss D: -0.1203
# Epoch 562, Loss G: 5.6571, Loss D: 0.0238
# Epoch 563, Loss G: 6.3621, Loss D: -0.1813
# Epoch 564, Loss G: 6.4639, Loss D: 0.1086
# Epoch 565, Loss G: 6.3639, Loss D: 0.0318
# Epoch 566, Loss G: 6.4257, Loss D: 0.0312
# Epoch 567, Loss G: 6.3431, Loss D: -0.2379
# Epoch 568, Loss G: 5.1337, Loss D: 0.0890
# Epoch 569, Loss G: 5.5981, Loss D: -0.1453
# Epoch 570, Loss G: 5.7745, Loss D: -0.0960
# Epoch 571, Loss G: 5.0484, Loss D: -0.1373
# Epoch 572, Loss G: 6.5173, Loss D: -0.0714
# Epoch 573, Loss G: 4.5492, Loss D: -0.0398
# Epoch 574, Loss G: 5.7855, Loss D: 0.1480
# Epoch 575, Loss G: 6.5005, Loss D: -0.1400
# Epoch 576, Loss G: 5.9349, Loss D: -0.2677
# Epoch 577, Loss G: 5.7176, Loss D: -0.0163
# Epoch 578, Loss G: 6.3753, Loss D: 0.0235
# Epoch 579, Loss G: 6.3550, Loss D: -0.0215
# Epoch 580, Loss G: 5.1578, Loss D: 0.1654
# Epoch 581, Loss G: 6.5190, Loss D: -0.0760
# Epoch 582, Loss G: 5.6925, Loss D: -0.1260
# Epoch 583, Loss G: 5.1918, Loss D: -0.1214
# Epoch 584, Loss G: 5.1443, Loss D: -0.0523
# Epoch 585, Loss G: 4.9607, Loss D: 0.2574
# Epoch 586, Loss G: 5.7228, Loss D: -0.2532
# Epoch 587, Loss G: 6.2831, Loss D: -0.0027
# Epoch 588, Loss G: 5.8322, Loss D: 0.1177
# Epoch 589, Loss G: 5.7565, Loss D: 0.1354
# Epoch 590, Loss G: 5.6745, Loss D: -0.0740
# Epoch 591, Loss G: 5.1575, Loss D: -0.1236
# Epoch 592, Loss G: 6.2192, Loss D: 0.0279
# Epoch 593, Loss G: 5.1787, Loss D: 0.1643
# Epoch 594, Loss G: 5.8392, Loss D: -0.2954
# Epoch 595, Loss G: 4.5733, Loss D: 0.1357
# Epoch 596, Loss G: 5.6351, Loss D: -0.1055
# Epoch 597, Loss G: 5.6182, Loss D: 0.0643
# Epoch 598, Loss G: 6.3056, Loss D: -0.1698
# Epoch 599, Loss G: 5.2205, Loss D: -0.0456
# Epoch 600, Loss G: 6.2813, Loss D: 0.1359
# Epoch 601, Loss G: 6.3845, Loss D: -0.1409
# Epoch 602, Loss G: 5.8232, Loss D: -0.1409
# Epoch 603, Loss G: 4.5237, Loss D: 0.0628
# Epoch 604, Loss G: 6.5270, Loss D: -0.0036
# Epoch 605, Loss G: 5.1329, Loss D: 0.1448
# Epoch 606, Loss G: 5.7842, Loss D: -0.0325
# Epoch 607, Loss G: 6.4036, Loss D: 0.0537
# Epoch 608, Loss G: 6.3523, Loss D: -0.0277
# Epoch 609, Loss G: 6.5003, Loss D: -0.1544
# Epoch 610, Loss G: 5.1724, Loss D: 0.1259
# Epoch 611, Loss G: 5.6984, Loss D: 0.0077
# Epoch 612, Loss G: 5.9413, Loss D: 0.0589
# Epoch 613, Loss G: 6.3877, Loss D: -0.0783
# Epoch 614, Loss G: 5.8006, Loss D: 0.1161
# Epoch 615, Loss G: 4.5882, Loss D: -0.0156
# Epoch 616, Loss G: 6.3950, Loss D: 0.0710
# Epoch 617, Loss G: 5.7877, Loss D: -0.0268
# Epoch 618, Loss G: 5.6856, Loss D: -0.0369
# Epoch 619, Loss G: 5.6028, Loss D: -0.0055
# Epoch 620, Loss G: 5.7540, Loss D: -0.1429
# Epoch 621, Loss G: 5.7284, Loss D: 0.0291
# Epoch 622, Loss G: 6.4174, Loss D: -0.0844
# Epoch 623, Loss G: 6.5148, Loss D: -0.0471
# Epoch 624, Loss G: 5.7555, Loss D: 0.0898
# Epoch 625, Loss G: 6.4927, Loss D: 0.1302
# Epoch 626, Loss G: 6.3872, Loss D: 0.1123
# Epoch 627, Loss G: 5.0162, Loss D: -0.0219
# Epoch 628, Loss G: 6.3886, Loss D: 0.0555
# Epoch 629, Loss G: 6.3707, Loss D: 0.0027
# Epoch 630, Loss G: 5.7174, Loss D: -0.1157
# Epoch 631, Loss G: 4.5613, Loss D: -0.3224
# Epoch 632, Loss G: 5.1636, Loss D: -0.0941
# Epoch 633, Loss G: 5.1128, Loss D: 0.1427
# Epoch 634, Loss G: 5.1828, Loss D: 0.1183
# Epoch 635, Loss G: 5.7665, Loss D: -0.0801
# Epoch 636, Loss G: 6.3194, Loss D: 0.0062
# Epoch 637, Loss G: 5.8563, Loss D: -0.0874
# Epoch 638, Loss G: 3.8852, Loss D: -0.2841
# Epoch 639, Loss G: 5.8336, Loss D: 0.0210
# Epoch 640, Loss G: 6.5009, Loss D: -0.0833
# Epoch 641, Loss G: 6.3841, Loss D: 0.0027
# Epoch 642, Loss G: 6.4382, Loss D: -0.2129
# Epoch 643, Loss G: 4.5619, Loss D: 0.0318
# Epoch 644, Loss G: 5.8378, Loss D: 0.0093
# Epoch 645, Loss G: 4.5519, Loss D: 0.0880
# Epoch 646, Loss G: 5.8217, Loss D: 0.0451
# Epoch 647, Loss G: 6.4171, Loss D: -0.0705
# Epoch 648, Loss G: 5.8574, Loss D: 0.1126
# Epoch 649, Loss G: 6.4167, Loss D: -0.0256
# Epoch 650, Loss G: 5.8523, Loss D: -0.0267
# Epoch 651, Loss G: 6.5443, Loss D: 0.0146
# Epoch 652, Loss G: 5.2370, Loss D: 0.1235
# Epoch 653, Loss G: 5.2621, Loss D: 0.0204
# Epoch 654, Loss G: 5.0488, Loss D: 0.1825
# Epoch 655, Loss G: 5.1529, Loss D: 0.0463
# Epoch 656, Loss G: 6.3216, Loss D: 0.0621
# Epoch 657, Loss G: 6.4817, Loss D: -0.0364
# Epoch 658, Loss G: 5.6738, Loss D: -0.0979
# Epoch 659, Loss G: 5.3113, Loss D: 0.0823
# Epoch 660, Loss G: 6.4273, Loss D: 0.0516
# Epoch 661, Loss G: 5.8788, Loss D: -0.1376
# Epoch 662, Loss G: 5.7239, Loss D: -0.0885
# Epoch 663, Loss G: 5.8306, Loss D: -0.1274
# Epoch 664, Loss G: 5.7410, Loss D: -0.0162
# Epoch 665, Loss G: 5.1616, Loss D: -0.1556
# Epoch 666, Loss G: 5.8003, Loss D: -0.0885
# Epoch 667, Loss G: 5.8736, Loss D: -0.0988
# Epoch 668, Loss G: 6.4001, Loss D: -0.1451
# Epoch 669, Loss G: 5.1231, Loss D: -0.0447
# Epoch 670, Loss G: 6.4912, Loss D: -0.0268
# Epoch 671, Loss G: 6.3560, Loss D: 0.0672
# Epoch 672, Loss G: 5.7695, Loss D: 0.1287
# Epoch 673, Loss G: 5.1378, Loss D: -0.0676
# Epoch 674, Loss G: 5.7626, Loss D: -0.2431
# Epoch 675, Loss G: 5.1620, Loss D: 0.0166
# Epoch 676, Loss G: 5.7438, Loss D: -0.1413
# Epoch 677, Loss G: 5.3049, Loss D: 0.0682
# Epoch 678, Loss G: 6.4305, Loss D: 0.0191
# Epoch 679, Loss G: 5.7439, Loss D: -0.1189
# Epoch 680, Loss G: 5.7139, Loss D: 0.2014
# Epoch 681, Loss G: 5.9371, Loss D: -0.2886
# Epoch 682, Loss G: 5.0983, Loss D: 0.0771
# Epoch 683, Loss G: 5.8387, Loss D: -0.0560
# Epoch 684, Loss G: 5.6542, Loss D: -0.0458
# Epoch 685, Loss G: 5.7801, Loss D: -0.1438
# Epoch 686, Loss G: 6.4029, Loss D: 0.0164
# Epoch 687, Loss G: 5.9151, Loss D: -0.0126
# Epoch 688, Loss G: 6.4833, Loss D: -0.0982
# Epoch 689, Loss G: 5.7667, Loss D: -0.0243
# Epoch 690, Loss G: 5.0859, Loss D: 0.0162
# Epoch 691, Loss G: 6.4002, Loss D: -0.0254
# Epoch 692, Loss G: 5.7290, Loss D: -0.1117
# Epoch 693, Loss G: 5.7692, Loss D: -0.1545
# Epoch 694, Loss G: 6.2025, Loss D: 0.2136
# Epoch 695, Loss G: 5.6029, Loss D: -0.1019
# Epoch 696, Loss G: 6.4108, Loss D: -0.0245
# Epoch 697, Loss G: 5.7274, Loss D: -0.2774
# Epoch 698, Loss G: 5.6812, Loss D: 0.0897
# Epoch 699, Loss G: 6.2850, Loss D: -0.0591
# Epoch 700, Loss G: 6.3584, Loss D: -0.2241
# Epoch 701, Loss G: 6.4341, Loss D: -0.1040
# Epoch 702, Loss G: 5.1788, Loss D: -0.1531
# Epoch 703, Loss G: 6.1996, Loss D: 0.0828
# Epoch 704, Loss G: 6.3189, Loss D: -0.0406
# Epoch 705, Loss G: 6.2465, Loss D: -0.1435
# Epoch 706, Loss G: 5.8076, Loss D: -0.0900
# Epoch 707, Loss G: 5.1265, Loss D: -0.0677
# Epoch 708, Loss G: 6.0207, Loss D: -0.0866
# Epoch 709, Loss G: 6.2509, Loss D: 0.0492
# Epoch 710, Loss G: 5.0610, Loss D: 0.0685
# Epoch 711, Loss G: 6.4621, Loss D: -0.0928
# Epoch 712, Loss G: 6.3324, Loss D: 0.0744
# Epoch 713, Loss G: 6.3345, Loss D: -0.0452
# Epoch 714, Loss G: 6.2234, Loss D: -0.0061
# Epoch 715, Loss G: 5.5810, Loss D: 0.0329
# Epoch 716, Loss G: 5.6208, Loss D: -0.0077
# Epoch 717, Loss G: 6.3795, Loss D: 0.0618
# Epoch 718, Loss G: 6.2528, Loss D: 0.1516
# Epoch 719, Loss G: 5.7711, Loss D: 0.0225
# Epoch 720, Loss G: 5.5751, Loss D: -0.0976
# Epoch 721, Loss G: 6.2961, Loss D: 0.0487
# Epoch 722, Loss G: 6.2908, Loss D: -0.1110
# Epoch 723, Loss G: 6.4635, Loss D: 0.1239
# Epoch 724, Loss G: 6.1045, Loss D: -0.2429
# Epoch 725, Loss G: 5.7605, Loss D: -0.1114
# Epoch 726, Loss G: 5.8716, Loss D: -0.0066
# Epoch 727, Loss G: 5.9124, Loss D: -0.1778
# Epoch 728, Loss G: 5.6379, Loss D: -0.0469
# Epoch 729, Loss G: 5.7026, Loss D: 0.0100
# Epoch 730, Loss G: 5.9249, Loss D: 0.0048
# Epoch 731, Loss G: 4.9949, Loss D: 0.0543
# Epoch 732, Loss G: 5.3417, Loss D: 0.1600
# Epoch 733, Loss G: 6.4586, Loss D: -0.2813
# Epoch 734, Loss G: 5.0741, Loss D: -0.1145
# Epoch 735, Loss G: 5.7601, Loss D: -0.1518
# Epoch 736, Loss G: 5.8579, Loss D: -0.0390
# Epoch 737, Loss G: 6.4160, Loss D: 0.1151
# Epoch 738, Loss G: 5.6549, Loss D: -0.1677
# Epoch 739, Loss G: 3.9616, Loss D: -0.0668
# Epoch 740, Loss G: 6.5180, Loss D: -0.0525
# Epoch 741, Loss G: 6.4531, Loss D: 0.0043
# Epoch 742, Loss G: 5.7417, Loss D: 0.0146
# Epoch 743, Loss G: 4.4436, Loss D: 0.0554
# Epoch 744, Loss G: 6.3558, Loss D: 0.1390
# Epoch 745, Loss G: 5.6987, Loss D: -0.0120
# Epoch 746, Loss G: 5.2375, Loss D: -0.0053
# Epoch 747, Loss G: 6.4625, Loss D: 0.0579
# Epoch 748, Loss G: 5.0841, Loss D: -0.0659
# Epoch 749, Loss G: 4.6137, Loss D: -0.0550
# Epoch 750, Loss G: 5.7742, Loss D: -0.1531
# Epoch 751, Loss G: 6.3296, Loss D: 0.0077
# Epoch 752, Loss G: 4.8956, Loss D: 0.0461
# Epoch 753, Loss G: 5.7361, Loss D: -0.1163
# Epoch 754, Loss G: 5.5947, Loss D: 0.0796
# Epoch 755, Loss G: 5.6548, Loss D: -0.0661
# Epoch 756, Loss G: 4.4413, Loss D: 0.0180
# Epoch 757, Loss G: 5.7253, Loss D: -0.0394
# Epoch 758, Loss G: 6.4960, Loss D: -0.0862
# Epoch 759, Loss G: 5.6979, Loss D: 0.1770
# Epoch 760, Loss G: 5.7219, Loss D: 0.0053
# Epoch 761, Loss G: 6.2480, Loss D: -0.0170
# Epoch 762, Loss G: 6.2471, Loss D: 0.0022
# Epoch 763, Loss G: 4.4187, Loss D: -0.1361
# Epoch 764, Loss G: 5.7891, Loss D: 0.1160
# Epoch 765, Loss G: 5.6224, Loss D: 0.0956
# Epoch 766, Loss G: 5.7538, Loss D: 0.0018
# Epoch 767, Loss G: 6.3405, Loss D: 0.0960
# Epoch 768, Loss G: 5.1970, Loss D: 0.0220
# Epoch 769, Loss G: 6.5588, Loss D: -0.2339
# Epoch 770, Loss G: 6.3217, Loss D: 0.0196
# Epoch 771, Loss G: 5.7571, Loss D: -0.0415
# Epoch 772, Loss G: 5.9253, Loss D: -0.0801
# Epoch 773, Loss G: 6.4414, Loss D: 0.1590
# Epoch 774, Loss G: 6.4523, Loss D: 0.0226
# Epoch 775, Loss G: 5.7660, Loss D: -0.0132
# Epoch 776, Loss G: 6.3440, Loss D: -0.1522
# Epoch 777, Loss G: 5.3125, Loss D: -0.0007
# Epoch 778, Loss G: 5.8550, Loss D: 0.0650
# Epoch 779, Loss G: 6.3715, Loss D: -0.0818
# Epoch 780, Loss G: 6.2656, Loss D: 0.1780
# Epoch 781, Loss G: 4.9488, Loss D: -0.0473
# Epoch 782, Loss G: 5.1452, Loss D: -0.2409
# Epoch 783, Loss G: 4.5524, Loss D: -0.0414
# Epoch 784, Loss G: 5.6857, Loss D: -0.0630
# Epoch 785, Loss G: 5.7411, Loss D: 0.1128
# Epoch 786, Loss G: 6.5021, Loss D: 0.1540
# Epoch 787, Loss G: 5.1963, Loss D: 0.0508
# Epoch 788, Loss G: 6.3489, Loss D: 0.0179
# Epoch 789, Loss G: 5.2376, Loss D: -0.0387
# Epoch 790, Loss G: 5.8365, Loss D: 0.0001
# Epoch 791, Loss G: 5.7150, Loss D: -0.0198
# Epoch 792, Loss G: 5.7222, Loss D: 0.0656
# Epoch 793, Loss G: 6.2142, Loss D: 0.1237
# Epoch 794, Loss G: 6.4085, Loss D: -0.0197
# Epoch 795, Loss G: 6.3667, Loss D: -0.1848
# Epoch 796, Loss G: 5.8933, Loss D: 0.0985
# Epoch 797, Loss G: 6.3444, Loss D: -0.0433
# Epoch 798, Loss G: 5.7406, Loss D: -0.1324
# Epoch 799, Loss G: 5.1675, Loss D: -0.0860
# Epoch 800, Loss G: 6.4474, Loss D: 0.0038
# Epoch 801, Loss G: 5.7929, Loss D: -0.0444
# Epoch 802, Loss G: 5.6179, Loss D: -0.1955
# Epoch 803, Loss G: 5.8643, Loss D: 0.0645
# Epoch 804, Loss G: 5.5763, Loss D: -0.0482
# Epoch 805, Loss G: 5.7222, Loss D: -0.0264
# Epoch 806, Loss G: 5.8122, Loss D: 0.1616
# Epoch 807, Loss G: 5.6047, Loss D: 0.1312
# Epoch 808, Loss G: 6.4848, Loss D: -0.0180
# Epoch 809, Loss G: 5.6654, Loss D: 0.0852
# Epoch 810, Loss G: 5.2240, Loss D: -0.1520
# Epoch 811, Loss G: 6.4178, Loss D: 0.1442
# Epoch 812, Loss G: 6.5321, Loss D: -0.2120
# Epoch 813, Loss G: 6.4948, Loss D: -0.1796
# Epoch 814, Loss G: 6.2491, Loss D: -0.0095
# Epoch 815, Loss G: 6.3250, Loss D: 0.1587
# Epoch 816, Loss G: 6.3603, Loss D: -0.1908
# Epoch 817, Loss G: 5.6912, Loss D: 0.0235
# Epoch 818, Loss G: 6.2158, Loss D: 0.0992
# Epoch 819, Loss G: 5.2639, Loss D: 0.0670
# Epoch 820, Loss G: 5.0368, Loss D: -0.1161
# Epoch 821, Loss G: 6.4473, Loss D: 0.0804
# Epoch 822, Loss G: 6.4032, Loss D: 0.0884
# Epoch 823, Loss G: 5.6690, Loss D: 0.1837
# Epoch 824, Loss G: 4.5543, Loss D: 0.0910
# Epoch 825, Loss G: 5.2287, Loss D: -0.0594
# Epoch 826, Loss G: 5.7933, Loss D: -0.1092
# Epoch 827, Loss G: 6.3532, Loss D: -0.1521
# Epoch 828, Loss G: 5.7452, Loss D: 0.1248
# Epoch 829, Loss G: 4.9420, Loss D: 0.0825
# Epoch 830, Loss G: 5.8160, Loss D: 0.0763
# Epoch 831, Loss G: 6.3545, Loss D: -0.0537
# Epoch 832, Loss G: 5.7110, Loss D: -0.0465
# Epoch 833, Loss G: 6.3071, Loss D: -0.1667
# Epoch 834, Loss G: 4.4594, Loss D: 0.0829
# Epoch 835, Loss G: 6.2312, Loss D: -0.1181
# Epoch 836, Loss G: 5.1743, Loss D: 0.0282
# Epoch 837, Loss G: 6.3457, Loss D: 0.2443
# Epoch 838, Loss G: 5.5395, Loss D: 0.0529
# Epoch 839, Loss G: 6.3956, Loss D: -0.0447
# Epoch 840, Loss G: 5.8030, Loss D: -0.0072
# Epoch 841, Loss G: 5.6644, Loss D: -0.0338
# Epoch 842, Loss G: 5.2460, Loss D: 0.0886
# Epoch 843, Loss G: 5.1108, Loss D: 0.1855
# Epoch 844, Loss G: 5.7036, Loss D: -0.1967
# Epoch 845, Loss G: 5.1752, Loss D: -0.1038
# Epoch 846, Loss G: 5.7891, Loss D: -0.1377
# Epoch 847, Loss G: 3.8229, Loss D: -0.1950
# Epoch 848, Loss G: 6.4389, Loss D: 0.0169
# Epoch 849, Loss G: 6.4063, Loss D: 0.0420
# Epoch 850, Loss G: 5.6954, Loss D: 0.2820
# Epoch 851, Loss G: 6.3183, Loss D: -0.0804
# Epoch 852, Loss G: 5.7270, Loss D: -0.0126
# Epoch 853, Loss G: 6.3651, Loss D: 0.0465
# Epoch 854, Loss G: 5.7395, Loss D: 0.0021
# Epoch 855, Loss G: 5.0963, Loss D: -0.0699
# Epoch 856, Loss G: 5.8467, Loss D: -0.1805
# Epoch 857, Loss G: 6.3127, Loss D: -0.0928
# Epoch 858, Loss G: 6.3689, Loss D: -0.0282
# Epoch 859, Loss G: 5.1617, Loss D: -0.0116
# Epoch 860, Loss G: 5.7250, Loss D: -0.0678
# Epoch 861, Loss G: 5.8065, Loss D: -0.0655
# Epoch 862, Loss G: 5.5243, Loss D: -0.0108
# Epoch 863, Loss G: 6.3887, Loss D: -0.1720
# Epoch 864, Loss G: 6.3145, Loss D: -0.0253
# Epoch 865, Loss G: 5.1023, Loss D: -0.1062
# Epoch 866, Loss G: 5.6725, Loss D: 0.0014
# Epoch 867, Loss G: 5.6365, Loss D: 0.1120
# Epoch 868, Loss G: 6.3266, Loss D: -0.0580
# Epoch 869, Loss G: 6.2936, Loss D: -0.0690
# Epoch 870, Loss G: 6.5273, Loss D: -0.2644
# Epoch 871, Loss G: 4.7949, Loss D: 0.1048
# Epoch 872, Loss G: 5.3083, Loss D: 0.0774
# Epoch 873, Loss G: 6.2284, Loss D: 0.0404
# Epoch 874, Loss G: 6.3820, Loss D: 0.1545
# Epoch 875, Loss G: 6.3880, Loss D: -0.2845
# Epoch 876, Loss G: 4.4301, Loss D: -0.1349
# Epoch 877, Loss G: 5.6845, Loss D: -0.0644
# Epoch 878, Loss G: 6.2617, Loss D: 0.1735
# Epoch 879, Loss G: 5.8429, Loss D: -0.1393
# Epoch 880, Loss G: 5.6929, Loss D: 0.0699
# Epoch 881, Loss G: 5.9482, Loss D: -0.1111
# Epoch 882, Loss G: 5.7443, Loss D: -0.0859
# Epoch 883, Loss G: 5.9800, Loss D: 0.0293
# Epoch 884, Loss G: 4.6308, Loss D: 0.0308
# Epoch 885, Loss G: 5.6975, Loss D: 0.0201
# Epoch 886, Loss G: 5.8379, Loss D: 0.0940
# Epoch 887, Loss G: 5.8421, Loss D: -0.0083
# Epoch 888, Loss G: 5.6834, Loss D: -0.1663
# Epoch 889, Loss G: 5.5822, Loss D: -0.1023
# Epoch 890, Loss G: 5.0054, Loss D: -0.0210
# Epoch 891, Loss G: 5.6240, Loss D: -0.1692
# Epoch 892, Loss G: 5.7411, Loss D: 0.0619
# Epoch 893, Loss G: 5.7823, Loss D: -0.0533
# Epoch 894, Loss G: 6.4260, Loss D: -0.0457
# Epoch 895, Loss G: 5.7072, Loss D: -0.1250
# Epoch 896, Loss G: 4.5265, Loss D: -0.0475
# Epoch 897, Loss G: 6.4921, Loss D: -0.3182
# Epoch 898, Loss G: 5.7905, Loss D: -0.0624
# Epoch 899, Loss G: 5.7264, Loss D: -0.0261
# Epoch 900, Loss G: 6.3575, Loss D: -0.1136
# Epoch 901, Loss G: 6.3747, Loss D: -0.0119
# Epoch 902, Loss G: 6.2298, Loss D: -0.1117
# Epoch 903, Loss G: 5.6487, Loss D: -0.1080
# Epoch 904, Loss G: 5.0506, Loss D: -0.0632
# Epoch 905, Loss G: 6.3300, Loss D: 0.1109
# Epoch 906, Loss G: 4.9566, Loss D: -0.1460
# Epoch 907, Loss G: 5.1434, Loss D: -0.1810
# Epoch 908, Loss G: 5.7756, Loss D: -0.0172
# Epoch 909, Loss G: 6.4336, Loss D: 0.1787
# Epoch 910, Loss G: 4.9841, Loss D: 0.0741
# Epoch 911, Loss G: 5.5637, Loss D: -0.0072
# Epoch 912, Loss G: 6.2938, Loss D: 0.1077
# Epoch 913, Loss G: 5.0213, Loss D: -0.0834
# Epoch 914, Loss G: 5.6958, Loss D: -0.0617
# Epoch 915, Loss G: 5.6592, Loss D: 0.0850
# Epoch 916, Loss G: 5.6187, Loss D: 0.0040
# Epoch 917, Loss G: 5.0385, Loss D: 0.0399
# Epoch 918, Loss G: 6.3329, Loss D: -0.1613
# Epoch 919, Loss G: 5.7969, Loss D: 0.0780
# Epoch 920, Loss G: 6.3154, Loss D: -0.0959
# Epoch 921, Loss G: 5.6934, Loss D: -0.0675
# Epoch 922, Loss G: 5.8011, Loss D: -0.1328
# Epoch 923, Loss G: 5.6527, Loss D: -0.0588
# Epoch 924, Loss G: 5.6757, Loss D: -0.0858
# Epoch 925, Loss G: 5.7762, Loss D: 0.0204
# Epoch 926, Loss G: 5.7575, Loss D: -0.1807
# Epoch 927, Loss G: 6.3094, Loss D: -0.1756
# Epoch 928, Loss G: 5.8354, Loss D: 0.1069
# Epoch 929, Loss G: 5.1662, Loss D: -0.0757
# Epoch 930, Loss G: 5.7030, Loss D: -0.3684
# Epoch 931, Loss G: 6.4509, Loss D: -0.0805
# Epoch 932, Loss G: 6.1936, Loss D: -0.1958
# Epoch 933, Loss G: 5.1668, Loss D: 0.0819
# Epoch 934, Loss G: 6.3036, Loss D: -0.0794
# Epoch 935, Loss G: 5.8541, Loss D: -0.0957
# Epoch 936, Loss G: 5.1054, Loss D: -0.0215
# Epoch 937, Loss G: 5.8403, Loss D: -0.1330
# Epoch 938, Loss G: 4.9873, Loss D: -0.0098
# Epoch 939, Loss G: 4.9687, Loss D: -0.1215
# Epoch 940, Loss G: 5.6143, Loss D: 0.0352
# Epoch 941, Loss G: 5.0300, Loss D: 0.0401
# Epoch 942, Loss G: 6.4692, Loss D: -0.1043
# Epoch 943, Loss G: 6.4142, Loss D: 0.0212
# Epoch 944, Loss G: 6.4877, Loss D: -0.0749
# Epoch 945, Loss G: 4.5157, Loss D: -0.0496
# Epoch 946, Loss G: 5.8247, Loss D: -0.0596
# Epoch 947, Loss G: 5.1820, Loss D: 0.2297
# Epoch 948, Loss G: 5.1238, Loss D: 0.1700
# Epoch 949, Loss G: 6.4354, Loss D: -0.0556
# Epoch 950, Loss G: 6.4095, Loss D: 0.0026
# Epoch 951, Loss G: 5.7263, Loss D: -0.1722
# Epoch 952, Loss G: 6.5163, Loss D: -0.1010
# Epoch 953, Loss G: 5.0782, Loss D: 0.1584
# Epoch 954, Loss G: 5.8749, Loss D: -0.0611
# Epoch 955, Loss G: 4.5943, Loss D: 0.0462
# Epoch 956, Loss G: 6.4668, Loss D: -0.0359
# Epoch 957, Loss G: 5.8287, Loss D: -0.0863
# Epoch 958, Loss G: 5.1416, Loss D: -0.0766
# Epoch 959, Loss G: 5.8656, Loss D: -0.0580
# Epoch 960, Loss G: 6.4363, Loss D: -0.0053
# Epoch 961, Loss G: 5.8179, Loss D: 0.0030
# Epoch 962, Loss G: 6.5412, Loss D: -0.0182
# Epoch 963, Loss G: 4.4638, Loss D: -0.0212
# Epoch 964, Loss G: 6.4423, Loss D: 0.0513
# Epoch 965, Loss G: 4.5704, Loss D: 0.0291
# Epoch 966, Loss G: 6.3047, Loss D: -0.1640
# Epoch 967, Loss G: 5.8696, Loss D: 0.0096
# Epoch 968, Loss G: 5.0742, Loss D: -0.1478
# Epoch 969, Loss G: 5.7839, Loss D: -0.0999
# Epoch 970, Loss G: 5.8663, Loss D: 0.0061
# Epoch 971, Loss G: 6.3332, Loss D: -0.0783
# Epoch 972, Loss G: 5.7146, Loss D: -0.1573
# Epoch 973, Loss G: 6.4959, Loss D: 0.0285
# Epoch 974, Loss G: 5.2074, Loss D: -0.1946
# Epoch 975, Loss G: 6.4416, Loss D: -0.1664
# Epoch 976, Loss G: 5.7611, Loss D: 0.0273
# Epoch 977, Loss G: 6.3979, Loss D: -0.0293
# Epoch 978, Loss G: 4.9814, Loss D: 0.0737
# Epoch 979, Loss G: 6.2519, Loss D: -0.0215
# Epoch 980, Loss G: 6.3354, Loss D: -0.0163
# Epoch 981, Loss G: 6.2350, Loss D: -0.0655
# Epoch 982, Loss G: 5.6031, Loss D: 0.0654
# Epoch 983, Loss G: 6.3514, Loss D: -0.1462
# Epoch 984, Loss G: 6.2877, Loss D: -0.0492
# Epoch 985, Loss G: 3.8902, Loss D: 0.2114
# Epoch 986, Loss G: 6.5146, Loss D: 0.0169
# Epoch 987, Loss G: 5.8298, Loss D: 0.0236
# Epoch 988, Loss G: 6.3084, Loss D: -0.0990
# Epoch 989, Loss G: 6.2880, Loss D: -0.1130
# Epoch 990, Loss G: 6.3961, Loss D: 0.1459
# Epoch 991, Loss G: 5.0167, Loss D: -0.1106
# Epoch 992, Loss G: 5.8404, Loss D: 0.1736
# Epoch 993, Loss G: 5.7316, Loss D: 0.0774
# Epoch 994, Loss G: 6.4981, Loss D: 0.0548
# Epoch 995, Loss G: 6.3305, Loss D: -0.2234
# Epoch 996, Loss G: 5.8093, Loss D: -0.2257
# Epoch 997, Loss G: 5.6716, Loss D: -0.1859
# Epoch 998, Loss G: 3.7562, Loss D: 0.0347
# Epoch 999, Loss G: 6.3482, Loss D: -0.0841
# Epoch 1000, Loss G: 5.6635, Loss D: -0.0043
# (100, 10)
# (537, 10)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7362cd2b2b4a> in <module>()
#      16 for sample in [samples1, samples2, samples3]:
#      17     sample.reset_index(drop=True, inplace=True)
# ---> 18     plot_tsne(sample, "./data_reduced.csv", f"_single_model_{sample.shape[0]}")
#
# <ipython-input-3-ac86d6b79151> in plot_tsne(gendata, actual_path, name, epoch)
#      20     gendata = pd.concat([gendata, labels_test], axis=1)
#      21     gendata.to_csv("./gendata.csv")
# ---> 22     gendata['label'] = gendata['label'].map(gen_map)
#      23
#      24     df.reset_index(drop=True, inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'
